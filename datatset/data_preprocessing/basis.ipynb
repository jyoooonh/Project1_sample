# %%
import pandas as pd

# %%
basis = pd.read_csv('../data/basis.csv', index_col=0, encoding='cp949')

# %%
basis = basis[::-1]

# %%
basis
# Out:
#                 종목코드              종목명    선물가격    현물가격  선물이론가격  시장베이시스  이론베이시스  \
# 일자
# 2022/10/04  101SC000  코스피200 F 202212  290.00  288.27  289.95    1.73    1.68
# 2022/10/05  101SC000  코스피200 F 202212  290.40  289.05  290.73    1.35    1.68
# 2022/10/06  101SC000  코스피200 F 202212  292.15  291.26  292.93    0.89    1.67
# 2022/10/07  101SC000  코스피200 F 202212  290.85  290.41  292.05    0.44    1.64
# 2022/10/11  101SC000  코스피200 F 202212  284.90  284.96  286.46   -0.06    1.50
# ...              ...              ...     ...     ...     ...     ...     ...
# 2023/10/25  101TC000  코스피200 F 202312  317.85  316.49  318.15    1.36    1.66
# 2023/10/26  101TC000  코스피200 F 202312  309.15  307.75  309.33    1.40    1.58
# 2023/10/27  101TC000  코스피200 F 202312  309.20  308.53  310.08    0.67    1.55
# 2023/10/30  101TC000  코스피200 F 202312  310.20  308.95  310.41    1.25    1.46
# 2023/10/31  101TC000  코스피200 F 202312  307.10  305.56  306.97    1.54    1.41
#
#              괴리율
# 일자
# ...

# %%
basis = basis.reset_index()

# %%
basis['괴리율'] = basis['괴리율'].shift(1)
basis['시장베이시스'] = basis['시장베이시스'].shift(1)
basis['이론베이시스'] = basis['이론베이시스'].shift(1)

# %%
basis = basis[8:259]

# %%
basis['일자'] = pd.to_datetime(basis['일자'])

# %%
basis
# Out:
#             일자      종목코드              종목명    선물가격    현물가격  선물이론가격  시장베이시스  \
# 8   2022-10-17  101SC000  코스피200 F 202212  289.35  289.57  291.09    1.54
# 9   2022-10-18  101SC000  코스피200 F 202212  294.50  293.59  295.12   -0.22
# 10  2022-10-19  101SC000  코스피200 F 202212  291.30  291.29  292.81    0.91
# 11  2022-10-20  101SC000  코스피200 F 202212  288.60  288.61  290.09    0.01
# 12  2022-10-21  101SC000  코스피200 F 202212  289.55  288.57  290.04   -0.01
# ..         ...       ...              ...     ...     ...     ...     ...
# 254 2023-10-16  101TC000  코스피200 F 202312  324.85  323.29  325.29    2.08
# 255 2023-10-17  101TC000  코스피200 F 202312  328.80  327.35  329.34    1.56
# 256 2023-10-18  101TC000  코스피200 F 202312  330.20  328.82  330.78    1.45
# 257 2023-10-19  101TC000  코스피200 F 202312  323.70  322.76  324.65    1.38
# 258 2023-10-20  101TC000  코스피200 F 202312  318.85  317.96  319.79    0.94
#
#      이론베이시스   괴리율
# 8      1.60 -0.02
# 9      1.52 -0.60
# 10     1.53 -0.21
# ...

# %%
basis[['일자', '시장베이시스', '이론베이시스', '괴리율']].reset_index(drop=True).to_csv('../year_clean_feature/basis_year.csv')

# %%
basis[116:][['일자', '시장베이시스', '이론베이시스', '괴리율']].reset_index(drop=True).to_csv('../half_clean_feature/basis_half.csv')

# %%
basis[197:][['일자', '시장베이시스', '이론베이시스', '괴리율']].reset_index(drop=True).to_csv('../quater_clean_feature/basis_quater.csv')
