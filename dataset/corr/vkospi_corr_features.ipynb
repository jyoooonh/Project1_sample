# %%
import pandas as pd

# %%
half = pd.read_csv('../half_features.csv', index_col=0)
half = half.drop('VKOSPI_Label', axis=1)

# %%
half
# Out:
#             시장베이시스  이론베이시스   괴리율  원위안 야간변동율  원엔 야간변동율  KOSPI 전날변동율  \
# 2023-04-10    1.49    1.97 -0.15      0.037     0.029         1.27
# 2023-04-11    1.57    1.86 -0.09      0.042     0.038         0.87
# 2023-04-12    1.28    1.83 -0.17      0.036     0.051         1.42
# 2023-04-13    1.36    1.79 -0.13      0.062     0.044         0.11
# 2023-04-14    1.21    1.75 -0.16      0.058     0.054         0.43
# ...            ...     ...   ...        ...       ...          ...
# 2023-09-26    1.52    1.96 -0.13      0.137     0.090        -0.49
# 2023-09-27    1.45    2.71 -0.38      0.124     0.112        -1.31
# 2023-10-04    2.29    2.67 -0.12      0.075     0.078         0.09
# 2023-10-05    0.65    2.38 -0.54      0.059     0.056        -2.41
# 2023-10-06    1.17    2.35 -0.37      0.054     0.053        -0.09
#
#             KOSPI 야간변동율  KS200 전날변동율  KS200 야간변동율  NAS 야간변동율  ...  S&P 당일변화량  \
# 2023-04-10        0.051         1.74       -0.028       0.76  ...      37.48
# ...
