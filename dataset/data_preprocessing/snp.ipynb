# %%
import pandas as pd

# %%
snp = pd.read_csv('../data/S&P500.csv', index_col=0)
snp
# Out:
#                     종가        시가        고가        저가  거래량    변동 %
# 날짜
# 2023- 10- 30  4,166.82  4,139.39  4,177.47  4,132.94  NaN   1.20%
# 2023- 10- 27  4,117.37  4,152.93  4,156.70  4,103.78  NaN  -0.48%
# 2023- 10- 26  4,137.23  4,175.99  4,183.60  4,127.90  NaN  -1.18%
# 2023- 10- 25  4,186.77  4,232.42  4,232.42  4,181.42  NaN  -1.43%
# 2023- 10- 24  4,247.68  4,235.79  4,259.38  4,219.43  NaN   0.73%
# ...                ...       ...       ...       ...  ...     ...
# 2022- 10- 19  3,695.16  3,703.11  3,728.58  3,666.51  NaN  -0.67%
# 2022- 10- 18  3,719.98  3,746.26  3,762.79  3,686.53  NaN   1.14%
# 2022- 10- 17  3,677.95  3,638.65  3,689.73  3,638.65  NaN   2.65%
# 2022- 10- 14  3,583.07  3,690.41  3,712.00  3,579.68  NaN  -2.37%
# 2022- 10- 13  3,669.91  3,520.37  3,685.41  3,491.58  NaN   2.60%
#
# [263 rows x 6 columns]

# %%
snp = snp[::-1]

# %%
snp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 263 entries, 2022- 10- 13 to 2023- 10- 30
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   종가      263 non-null    object
#  1   시가      263 non-null    object
#  2   고가      263 non-null    object
#  3   저가      263 non-null    object
#  4   거래량     0 non-null      float64
#  5   변동 %    263 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 14.4+ KB

# %%
snp = snp.reset_index()

# %%
snp = snp[['날짜', '종가', '시가', '고가', '저가', '변동 %']]

# %%
snp['변동 %'] = snp['변동 %'].astype(str)
snp["변동 %"] = snp["변동 %"].str.rstrip('%')
snp["변동 %"] = snp["변동 %"].astype(float)

snp["시가"] = snp["시가"].str.replace(',', '')
snp["시가"] = snp["시가"].astype(float)

snp["종가"] = snp["종가"].str.replace(',', '')
snp["종가"] = snp["종가"].astype(float)

snp["고가"] = snp["고가"].str.replace(',', '')
snp["고가"] = snp["고가"].astype(float)

snp["저가"] = snp["저가"].str.replace(',', '')
snp["저가"] = snp["저가"].astype(float)

# %%
snp['변동 %'] = snp['변동 %'].shift(1)
snp
# Out:
#                날짜       종가       시가       고가       저가  변동 %
# 0    2022- 10- 13  3669.91  3520.37  3685.41  3491.58   NaN
# 1    2022- 10- 14  3583.07  3690.41  3712.00  3579.68  2.60
# 2    2022- 10- 17  3677.95  3638.65  3689.73  3638.65 -2.37
# 3    2022- 10- 18  3719.98  3746.26  3762.79  3686.53  2.65
# 4    2022- 10- 19  3695.16  3703.11  3728.58  3666.51  1.14
# ..            ...      ...      ...      ...      ...   ...
# 258  2023- 10- 24  4247.68  4235.79  4259.38  4219.43 -0.17
# 259  2023- 10- 25  4186.77  4232.42  4232.42  4181.42  0.73
# 260  2023- 10- 26  4137.23  4175.99  4183.60  4127.90 -1.43
# 261  2023- 10- 27  4117.37  4152.93  4156.70  4103.78 -1.18
# 262  2023- 10- 30  4166.82  4139.39  4177.47  4132.94 -0.48
#
# [263 rows x 6 columns]

# %%
snp['당일 변동률'] = round((snp['종가'] - snp['시가']) / snp['시가'] * 100, 3)
snp['당일 변화량'] = round(snp['고가'] - snp['저가'], 3)

# %%
snp['당일 변동률'] = snp['당일 변동률'].shift(1)
snp['당일 변화량'] = snp['당일 변화량'].shift(1)

# %%
snp = snp.dropna()

# %%
snp = snp[1:256]

# %%
snp = snp.reset_index(drop=True)

# %%
snp['날짜'] = pd.to_datetime(snp['날짜'])

# %%
snp[119:245].reset_index(drop=True)[['날짜', '변동 %', '당일 변동률', '당일 변화량']].to_csv('../half_clean_feature/snp_half.csv')

# %%
snp[163:245].reset_index(drop=True)[['날짜', '변동 %', '당일 변동률', '당일 변화량']].to_csv('../quater_clean_feature/snp_quater.csv')

# %%
snp[201:245].reset_index(drop=True)[['날짜', '변동 %', '당일 변동률', '당일 변화량']].to_csv('../two_month_clean_feature/snp_2month.csv')

# %%
snp[201:245]
# Out:
#             날짜       종가       시가       고가       저가  변동 %  당일 변동률  당일 변화량
# 201 2023-08-07  4518.44  4491.58  4519.84  4491.15 -0.53  -0.796   65.79
# 202 2023-08-08  4499.38  4498.03  4503.31  4464.39  0.90   0.598   28.69
# 203 2023-08-09  4467.71  4501.57  4502.44  4461.33 -0.42   0.030   38.92
# 204 2023-08-10  4468.83  4487.16  4527.37  4457.92 -0.70  -0.752   41.11
# 205 2023-08-11  4464.05  4450.69  4476.23  4443.98  0.03  -0.408   69.45
# 206 2023-08-14  4489.72  4458.13  4490.33  4453.44 -0.11   0.300   32.25
# 207 2023-08-15  4437.86  4478.87  4478.87  4432.19  0.58   0.709   36.89
# 208 2023-08-16  4404.33  4433.79  4449.95  4403.55 -1.16  -0.916   46.68
# 209 2023-08-17  4370.36  4416.32  4421.17  4364.83 -0.76  -0.664   46.40
# 210 2023-08-18  4369.71  4344.88  4381.82  4335.31 -0.77  -1.041   56.34
# 211 2023-08-21  4399.77  4380.28  4407.55  4360.30 -0.01   0.571   46.51
# 212 2023-08-22  4387.55  4415.33  4418.59  4382.77  0.69   0.445   47.25
# 213 2023-08-23  4436.01  4396.44  4443.18  4396.44 -0.28  -0.629   35.82
# 214 2023-08-24  4376.31  4455.16  4458.30  4375.55  1.10   0.900   46.74
